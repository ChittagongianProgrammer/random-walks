# %% [markdown]
# Random Number Generator

# %%
# Import numpy as np
import numpy as np
# Set the seed
np.random.seed(123)

# Generate and print random float
number = np.random.rand()
print(number)
# Out:
# 0.6964691855978616

# %% [markdown]
# Dice

# %%
# Import numpy and set seed
import numpy as np

# Seed makes the outcomes the same always for analysis 
np.random.seed(123)

# Use randint() to simulate a dice
print(np.random.randint(1,7))
# Use randint() again
print(np.random.randint(1,7))
# Out:
# 6
# 3

# %% [markdown]
# Determine your next move

# %%
import numpy as np 
np.random.seed(123)
# Starting step
step = 50

# Roll the dice
dice = np.random.randint(1,7)

# Finish the control construct
if dice <= 2 :
    step = step - 1
elif dice in [3,4,5]  :
    step = step + 1
else:
    step = step + np.random.randint(1,7)

# Print out dice and step
print(dice)
print(step)
# Out:
# 6
# 53

# %% [markdown]
# Random Walk

# %%
import numpy as np
np.random.seed(123)

# Initialize random_walk
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        # Replace below: use max to make sure step can't go below 0
        step = max(0, step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

print(random_walk)

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Plot random_walk
plt.plot(random_walk)

plt.xlabel('Steps taken')
plt.ylabel('Floor reached')
plt.title('A random walk up a 100 floor building')

# Show the plot
plt.show()
# Out:
# [0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, 0, 1, 6, 5, 4, 5, 4, 5, 6, 7, 8, 9, 8, 9, 8, 9, 10, 11, 12, 11, 15, 16, 15, 16, 15, 16, 17, 18, 19, 20, 21, 22, 25, 26, 27, 28, 33, 34, 38, 39, 38, 39, 40, 39, 40, 41, 43, 44, 45, 44, 43, 44, 45, 44, 43, 44, 45, 47, 46, 45, 46, 45, 46, 47, 48, 50, 49, 50, 51, 52, 53, 54, 53, 52, 53, 52, 53, 54, 53, 56, 57, 58, 59, 58, 59, 60]

# %% [markdown]
# Visualisation of 5 random walks

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(123)

all_walks = []
for i in range(5) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to NumPy array: np_aw
np_aw = np.array(all_walks)

# Plot np_aw and show
plt.xlabel('Steps taken')
plt.ylabel('Floor reached')
plt.title('5 random walks up a 100 floor building')
plt.plot(np_aw)
plt.show()
# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)

# Plot np_aw_t and show
plt.xlabel('Steps taken')
plt.ylabel('Floor reached')
plt.title('5 random walks up a 100 floor building')
plt.plot(np_aw_t)
plt.show()

# %% [markdown]
# Visualisation of 20 walks with a 0.5% of falling from being clumsy

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(123)

plt.clf()

# Simulate random walk 20 times
all_walks = []
for i in range(20) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if np.random.rand() <= 0.005 :
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.xlabel('Steps taken')
plt.ylabel('Floor reached')
plt.title('20 random walks up a building with a 0.5% chance of falling')
plt.plot(np_aw_t)
plt.show()

# %% [markdown]
# Histogram showing outcomes of 500 random walks and showing the distribution of final positions after 100 steps

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(123)

plt.clf()

# Simulate random walk 500 times
all_walks = []
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))

# Select last row from np_aw_t: ends
ends = np_aw_t[-1]

# Plot histogram of ends, display plot
plt.xlabel('Floors of the building')
plt.ylabel('Number of times reached a certain floor')
plt.title('A histogram showing the distribution of final positions (end points) after 100 steps in 500 random walks')
plt.hist(ends)
plt.show()

# %% [markdown]
# The resulting histogram visually represents the outcomes of 500 random walks, showing the distribution of final positions after 100 steps. This simulation is used to estimate the probabilities of reaching different floors in the Empire State Building game.
